# %% [markdown]
# # Observação: namespaces
#
# Talvez você já tenha percebido que ao executarmos comandos, nos referimos ao módulo em que o comando está definido. Por exemplo, para usar a função transpose do módulo numpy, que importamos como np, usamos o comando
#
# np.transpose(A)
#
# isso significa que a função transpose que estamos utilizando "mora" dentro do módulo numpy.
#
# Exemplo:

# %%
import math
import numpy
import scipy.constants

print(math.pi, "do módulo math")
print(numpy.pi, "do módulo numpy")
print(scipy.constants.pi, "do módulo scipy")
# Out:
# 3.141592653589793 do módulo math
# 3.141592653589793 do módulo numpy
# 3.141592653589793 do módulo scipy

# %%
import math as matematica

# %%
matematica.pi
# Out:
# 3.141592653589793

# %%
import math as biblioteca

# %%
biblioteca.pi
# Out:
# 3.141592653589793

# %%
import numpy as np

# %%
np.pow(2,8)
# Out:
# np.int64(256)

# %% [markdown]
# # matplotlib
#
# A biblioteca matplotlib, e em particular seu módulo matplotlib.pyplot, permites ao usuário fazer gráficos com uma sintaxe parecida com o que é feito no MATLAB.
#
# Cada função executa uma ação em uma figura. Por exemplo, para fazer um gráfico simples, usamos algo do tipo

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4])
plt.ylabel('meus números')
plt.show()

# %% [markdown]
# Como queremos que os gráficos fiquem embutidos no notebook, podemos usar a linha

# %%
# %matplotlib inline

# %% [markdown]
# ou

# %%
# %matplotlib notebook

# %% [markdown]
# **Atenção** Como vimos em aula, em algumas instalações a opção notebook não funciona corretamente; aconselho sempre que estiverem usando notebooks, usarem
#
# %matplotlib inline

# %%
# %matplotlib inline

# %% [markdown]
# Agora, podemos usar comandos no estilo MATLAB:

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4])
plt.ylabel('meus números')
plt.show()

# %% [markdown]
# **Observação** Os exemplos abaixo foram baseados no tutorial http://matplotlib.org/users/pyplot_tutorial.html

# %% [markdown]
# Para desenhar um gráfico, precisamos passar ao matplotlib uma lista de valores para o eixo horizontal, e outra lista de valores (com o mesmo tamanho da primeira) para o eixo vertical; ligando estes pontos, o matplotlib desenha o gráfico. Se passamos apenas uma lista para o matplotlib, ele conclui que esta lista contém os valores a serem colocados no eixo vertical.
#
# Se quisermos escolher valores para o eixo horizontal, fazemos matplotlib.pyplot.plot(x,y):

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.show()

# %% [markdown]
# Perceba que, para que o gráfico esteja na janela correta, precisamos usar uma sintaxe um pouco diferente do que usaríamos no MATLAB:

# %% [markdown]
# 1. Crie uma lista com os 20 primeiros múltiplos de 3, iniciando do 0. Isso será seus dados do eixo x (horisontal);
# 2. Criar uma lista com log, da biblioteca math, de cada um dos itens da lista anterior. Isso será dados do eixo y (vertical);
# 3. Criar o gráfico com o recurso plot do matplotlib.pyplot.

# %%
import math
import matplotlib.pyplot as plt

# 1. Cria a lista com os 20 primeiros múltiplos de 3 (iniciando do 0)
eixo_x_completo = [3 * i for i in range(20)]

# 2. Cria a lista do eixo Y (calculando o log apenas para números maiores que 0)
eixo_x = []
eixo_y = []

for x in eixo_x_completo:
    if x > 0:
        eixo_x.append(x)
        eixo_y.append(math.log(x))
    else:
        print(f"Aviso: O número {x} foi desconsiderado pois log(0) é indefinido.")

# 3. Cria o gráfico com o matplotlib
plt.figure(figsize=(8, 5))
plt.plot(eixo_x, eixo_y, marker='o', color='blue', linestyle='-')

# Customização do gráfico
plt.title('Logaritmo Natural dos Múltiplos de 3')
plt.xlabel('Múltiplos de 3 (Eixo X)')
plt.ylabel('log(x) (Eixo Y)')
plt.grid(True)

# Exibe o gráfico
plt.show()
# Out:
# Aviso: O número 0 foi desconsiderado pois log(0) é indefinido.

# %%
fig = plt.figure()
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])

# %% [markdown]
# Também podemos selecionar o tipo de traço e a cor, usando exatamente a mesma sintaxe que o MATLAB:

# %%
fig = plt.figure()
plt.plot([1,2,3,4], [1,4,9,16], 'ro')
plt.plot([1,2,3,4],[1,4,9,16], 'g', linewidth=2)
plt.plot([1,3,5,7,9], linestyle="dashed", linewidth=4)

# %%
import numpy as np
import matplotlib.pyplot as plt

# t vai de 0 a 5, com subintervalos de 0.2 unidades de comprimento
t = np.arange(0., 5., 0.2)

fig = plt.figure()
# em tracejado vermelho faremos o gráfico de t; 
# em quadrados azuis faremos o gráfico de t**2;
# em triângulos verdes faremos o gráfico de t**3
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %%
fig = plt.figure()
plt.plot([1,3,2,7,5,9,4], 'y*', markersize=20)

# %% [markdown]
# O comando axis permite ajustarmos os limites horizontais e verticais do gráfico:

# %%
fig = plt.figure()
plt.plot([1,3,2,7,5,9,4], 'y*', markersize=20)
plt.axis([-1,8,0,10])
# Out:
# [-1, 8, 0, 10]

# %% [markdown]
# ### Múltiplos gráficos na mesma janela
#
# No pyplot, assim como no MATLAB, temos um conceito de figura e axes (eixos). Todos os comandos de gráfico se aplicam ao eixo atual. A função gca() retorna uma referência ao eixo atual e gcf() retorna a figura atual.

# %% [markdown]
# Por exemplo, podemos usar

# %%
fig, axes = plt.subplots()
pontos = [1,3,2,7,5,9,4]
axes.plot(pontos, 'y*', markersize=20)
axes.plot(pontos, 'b', linestyle="dotted")
axes.axis([-1,8,0,10])
# Out:
# [-1, 8, 0, 10]

# %% [markdown]
# Agora, vamos criar uma janela com dois subplots:

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure(1)
plt.subplot(211)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.show()

# %% [markdown]
# O comando subplot() especifica (linha, coluna, figura) em que figura vai de 1 até linhas*colunas (As vírgulas são opcionais se linhas*colunas<10; então subplot(211) é o mesmo que subplot(2, 1, 1).

# %%
import matplotlib.pyplot as plt
plt.figure(1)                # primeira figura
plt.subplot(211)             # primeiro subplot na primeira figura
plt.plot([1, 2, 3])
plt.subplot(212)             # segundo subplot na primeira figura
plt.plot([4, 5, 6])


plt.figure(2)                # segunda figura
plt.plot([4, 5, 6])          # cria um subplot(111) automaticamente

plt.figure(1)                # na figura 1, o subplot(212) ainda é o mais atual
plt.subplot(211)             # selecionar o subplot(211) como atual
plt.title('Easy as 1, 2, 3') # atualizar o título do subplot(211)
# Out:
# Text(0.5, 1.0, 'Easy as 1, 2, 3')

# %% [markdown]
# ### Adicionando anotações
#
# O comando text() pode ser utilizado para adicionarmos texto em posições arbitrárias, enquanto que xlabel(), ylabel() e title() são utilizados para adicionar texto em posições pré-definidas:

# %%
import numpy as np
import matplotlib.pyplot as plt

mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

fig = plt.figure(1)
n, bins, patches = plt.hist(x, 50, density=True, facecolor='g', alpha=0.75)

plt.xlabel('Domínio')
plt.ylabel('Probabilidade')
plt.title('Histograma')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

fig = plt.figure(1)
n, bins, patches = plt.hist(x, 50, density=True, facecolor='g', alpha=0.75)

plt.xlabel('Domínio')
plt.ylabel('Probabilidade')
plt.title('Histograma')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)

t = plt.xlabel('Dados', fontsize=14, color='red')

plt.show()

# %% [markdown]
# (O r antes da string do título é importante pois significa que o Python não deve tentar interpretar o que se segue)

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)
line, = ax.plot(t, s, lw=2)

ax.annotate('máximo local', xy=(2, 1), xytext=(3, 1.5),
            arrowprops=dict(facecolor='black', shrink=0.05),
            )

plt.ylim(-2,2)
# Out:
# (-2.0, 2.0)

# %% [markdown]
# Podemos selecionar a escala do gráfico usando
#
#     plt.xscale(‘log’)
#
# por exemplo.

# %%
import numpy as np
import matplotlib.pyplot as plt

# inventar dados no intervalo ]0, 1[
y = np.random.normal(loc=0.5, scale=0.4, size=1000)
y = y[(y > 0) & (y < 1)]
y.sort()
x = np.arange(len(y))

# criar gráficos com diversas escalas
plt.figure()

# linear
plt.subplot(221)
plt.plot(x, y)
plt.yscale('linear')
plt.title('linear')
plt.grid(True)

# log
plt.subplot(222)
plt.plot(x, y)
plt.yscale('log')
plt.title('log')
plt.grid(True)

# log simétrico
plt.subplot(223)
plt.plot(x, y - y.mean())
# CORREÇÃO: 'linthreshy' alterado para 'linthresh'
plt.yscale('symlog', linthresh=0.05)
plt.title('symlog')
plt.grid(True)

# logit
plt.subplot(224)
plt.plot(x, y)
plt.yscale('logit')
plt.title('logit')
plt.grid(True)

# Dica: ajusta o espaçamento para os títulos não cortarem
plt.tight_layout() 
plt.show()

# %% [markdown]
# ## Gráficos 3D

# %% [markdown]
# Agora, se você puder, utilize a opção abaixo:

# %%
# %matplotlib notebook

# %% [markdown]
# Caso contrário, execute os comandos abaixo diretamente no console do python ou em algum editor de código, como por exemplo o Spyder (incluido no Anaconda)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
# Out:
# <div id='5ec6ee88-a8ff-45b9-82f1-73966f01249d'></div>

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
from matplotlib import cm

fig = plt.figure()
# CORREÇÃO: Criando o eixo 3D da forma atualizada
ax = fig.add_subplot(projection='3d')

# Dados de teste embutidos
X, Y, Z = axes3d.get_test_data(0.05)

ax.plot_surface(X, Y, Z, rstride=8, cstride=8, alpha=0.3)
cset = ax.contour(X, Y, Z, zdir='z', offset=-100, cmap=cm.coolwarm)
cset = ax.contour(X, Y, Z, zdir='x', offset=-40, cmap=cm.coolwarm)
cset = ax.contour(X, Y, Z, zdir='y', offset=40, cmap=cm.coolwarm)

ax.set_xlabel('X')
ax.set_xlim(-40, 40)
ax.set_ylabel('Y')
ax.set_ylim(-40, 40)
ax.set_zlabel('Z')
ax.set_zlim(-100, 100)

plt.show()
# Out:
# <div id='e157ac79-d560-4b1d-98d4-c1704038cc5d'></div>

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d.axes3d import get_test_data
# Vamos importar também da matplotlib uma biblioteca de colormaps
from matplotlib import cm

# Apenas para acertar o tamanho do gráfico.
fig = plt.figure(figsize=plt.figaspect(0.5))

# 1o Subplot
ax = fig.add_subplot(1, 2, 1, projection='3d')
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)
surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
ax.set_zlim3d(-1.01, 1.01)

fig.colorbar(surf, shrink=0.5, aspect=10)

# 2o Subplot
ax = fig.add_subplot(1, 2, 2, projection='3d')

# A linha abaixo usa dados de teste embutidos no matplotlib. Você pode preencher com os dados que lhe interessam.
X, Y, Z = get_test_data(0.05)
ax.plot_wireframe(X, Y, Z, rstride=10, cstride=10)

plt.show()
# Out:
# <div id='e18c5ebd-a9bc-4b56-b2de-0ba804c1d19c'></div>

# %% [markdown]
# Para mais informações, visite http://matplotlib.org/mpl_toolkits/mplot3d/tutorial.html

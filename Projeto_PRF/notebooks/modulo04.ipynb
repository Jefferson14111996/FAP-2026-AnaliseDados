# %% [markdown]
# Módulo 4 - Preparação dos Dados com Python

# %%
## Biblioteca principal do modulo 4
try:
    import pandas as pd
except ModuleNotFoundError:
    import subprocess
    import sys
    subprocess.check_call([sys.executable, "-m", "pip", "install", "pandas"])
    import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from datetime import datetime
import unicodedata


pd.set_option("display.max_columns", 120) 
pd.set_option("display.width", 160)
# Out:
# Collecting pandas
#   Downloading pandas-3.0.5-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pandas) (2.5.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.5-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (11.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 22.9 MB/s  0:00:00m0:00:010:01
# Installing collected packages: pandas
# Successfully installed pandas-3.0.5
# [notice] A new release of pip is available: 26.0.1 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip

# %%
# Estrutura padrão do projeto​

RAIZ = Path(".")​

PASTAS = [​

"dados_brutos", "dados_tratados",​

"notebooks", "sql", "dashboards",​

"relatorios", "apresentacao", "logs"​

]​

for pasta in PASTAS:​

(RAIZ / pasta).mkdir(​

parents=True, exist_ok=True)​

​

print("Pastas verificadas/criadas:")​

for pasta in PASTAS:​

print("-", RAIZ / pasta)​
